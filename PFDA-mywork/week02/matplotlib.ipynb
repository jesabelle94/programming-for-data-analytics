# %%
import matplotlib.pyplot as plt
import numpy as np

# https://matplotlib.org/stable/users/explain/quick_start.html

# %%
# create some data
# np.arrange90 will create a series

x = 0.5 + np.arange(8)
y = [1,3,5,8,3,6,4,6]
y2 = [3,5,6,9,4,9.1,4.6,7.7,8]

# %%
# making a plot using fig, ax = plt.subplots() AND plt.show()
# and make your plot eg bar

fig, ax = plt.subplots()

ax.bar(x,y)
ax.plot (x,y)
#ax.scatter(x,y)
#ax.fill_between(x,y)
#ax.stackplot(x,y)
#ax.stairs(y)
#ax.stem(x,y)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# set()
# setting parametes on plot using set()

fig, ax = plt.subplots()

ax.bar(x,y)
ax.plot (x,y)

# ax.set(xlabel="x axis label", ylabel="y", title="hey mom")

#OR

ax.set_title("yo mamma")
ax.set_xlabel("x here")
ax.set_ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %%
def currency_formatter(x,pos):
    s = f"${x}M"
    return s

# %% [markdown]
# ### Format the labels
#
# Use a formatter function to format the labels using
#
# ax.xaxis.set_major_formatter(formatter_fun)
#
# The function that will do the formatting
#
# It takes two parameters the value on the axis and the position of the tick It should return text as it should appear

# %%
fig, ax = plt.subplots()

ax.bar(x,y)
ax.plot(x,y)

ax.set_title("yo mamma")
ax.set_xlabel("x here")
ax.set_ylabel("y")

ax.xaxis.set_major_formatter(currency_formatter)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')


plt.show()

# %% [markdown]
# ## Annotations
#
# ax.annotate('text', (x_pointer, y_pointer), xytext=(x, y))

# %%
fig, ax = plt.subplots()

ax.bar(x,y)
ax.plot(x,y)

ax.set_title("yo mamma")
ax.set_xlabel("x here")
ax.set_ylabel("y")

#ax.text(1, 8, "blah", fontsize=10, verticalalignment="center")
ax.annotate('max', (3.2, 8), xytext=(1, 9),arrowprops=dict(facecolor='black', shrink=0.05))

ax.xaxis.set_major_formatter(currency_formatter)

labels = ax.get_xticklabels()
plt.setp(labels, rotation=45, horizontalalignment='right')


plt.show()
