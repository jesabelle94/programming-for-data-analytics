# %% [markdown]
# ### Weather plot of the temperate over time ###
# Author: Jenny Isabelle Formentera

# %%
# Pandas allows us to investigate CSV files
import pandas as pd

# %%
# Create plots for specific data eg. bar, scatter, hist, etc.
# Reference: https://matplotlib.org/stable/users/explain/quick_start.html
import matplotlib.pyplot as plt

# %%
# reads a file and lead to this file path
weather = pd.read_csv('/Users/jennyformentera/Desktop/programming-for-data-analytics/PFDA-assignments/weatherreadings1.csv')

# %%
weather.head()
# Out:
#                                  siteId        reportStartDateTime  \
# 0  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:15:00+00:00
# 1  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T16:45:00+00:00
# 2  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:00:00+00:00
# 3  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:15:00+00:00
# 4  f2d42aea-f516-ec11-b76a-0003ff599499  2024-10-02T17:30:00+00:00
#
#            reportEndDateTime  collectionName  isPublic  isLatestVersion  \
# 0  2024-10-02T16:15:00+00:00               1      True             True
# 1  2024-10-02T16:45:00+00:00               1      True             True
# 2  2024-10-02T17:00:00+00:00               1      True             True
# 3  2024-10-02T17:15:00+00:00               1      True             True
# 4  2024-10-02T17:30:00+00:00               1      True             True
#
#    observationType softwareType  windDirection  relativeHumidity  ...  isDcnn  \
# ...

# %%
# describe this data
weather.describe()
# Out:
#        collectionName  observationType  windDirection  relativeHumidity  \
# count            89.0             89.0      89.000000         89.000000
# mean              1.0              1.0     188.292135         85.135955
# std               0.0              0.0     144.536579          5.626101
# min               1.0              1.0       0.000000         70.400000
# 25%               1.0              1.0      40.000000         79.900000
# 50%               1.0              1.0     275.000000         87.200000
# 75%               1.0              1.0     333.000000         89.400000
# max               1.0              1.0     359.000000         92.400000
#
#        windSpeed_MilePerHour  windSpeed_MetrePerSecond  \
# count              89.000000                 89.000000
# mean                2.866067                  1.281245
# std                 2.637010                  1.178847
# min                 0.000000                  0.000000
# ...

# %% [markdown]
# ## Create A Plot

# %%
fig, ax = plt.subplots(figsize=(8, 6))

ax.plot(weather.index, weather['dryBulbTemperature_Celsius'], color='lightblue', label='Dry Bulb')
ax.scatter(weather.index, weather['wetBulbTemperature_Celsius'], color='lightpink', label="Wet Bulb")

# Set title and labels to make it pretty
ax.set_title('Dry & Wet Bulb Temperature Over Time')
ax.set_xlabel("Time")
ax.set_ylabel('Temperature (°C)')
ax.grid()
plt.legend(title='Type')

plt.show()

# %% [markdown]
# ### End
